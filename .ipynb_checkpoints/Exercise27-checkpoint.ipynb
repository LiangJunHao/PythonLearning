# %% [markdown]
# # Exercise 27. Memorizing Logic

# %% [markdown]
# ## Introduction

# %% [markdown]
# From now on, you will be learning logic. You won’t learn complex theories that academics love to study but just the basic logic that makes real programs work and that real programmers need every day.

# %% [markdown]
# It will not be fun at first. It will be downright boring and tedious, **but** this will teches ou a very important skill you will need as a programmer.

# %% [markdown]
# ## Tips

# %% [markdown]
# Do a tiny bit at a time throughtout the day and mark down what you need to work on most.
#
# Do not try to sit down for two hours straight and memorize these tables. This won’t work.
#
# Instead, create a bunch of index cards with each column on the left (True or False) on the front, and the column on the right on the back.
#
# **Do not spend more than one week on this, because you will be applying it as you go.**

# %%
from IPython.display import Image
Image(filename="img/ex27_1.jpg",width=200, height=100)

# %%
Image(filename="img/ex27_2.jpg",width=200, height=100)

# %%
Image(filename="img/ex27_3.jpg",width=200, height=100)

# %%
Image(filename="img/ex27_4.jpg",width=200, height=100)

# %%
Image(filename="img/ex27_5.jpg",width=200, height=100)

# %%
Image(filename="img/ex27_6.jpg",width=200, height=100)

# %%
Image(filename="img/ex27_7.jpg",width=200, height=100)
